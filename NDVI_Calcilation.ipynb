# %%
# import os
# import glob
# import rasterio
# import numpy as np
# import re # For using regular expressions to extract scene IDs

# def calculate_ndvi(red_file_path, nir_file_path, output_file_path):
#     """
#     Calculates NDVI from Red and NIR band files and saves the result.
#     (This function remains largely the same as the previous rasterio version,
#      assuming input Red and NIR bands need scaling if they are raw Landsat values)
#     """
#     try:
#         # --- Define Landsat Collection 2 Level 2 scaling factors ---
#         # If your "Red_band(...)" files are already reflectance (0-1),
#         # set scale_factor = 1.0 and offset = 0.0
#         # If they are raw scaled integers from Landsat SR products:
#         scale_factor = 0.0000275
#         offset = -0.2
        
#         with rasterio.open(red_file_path) as red_src:
#             red_profile = red_src.profile
#             red_int = red_src.read(1).astype('float32')
#             red = (red_int * scale_factor) + offset
#             if red_src.nodata is not None:
#                 red[red_int == red_src.nodata] = np.nan

#         with rasterio.open(nir_file_path) as nir_src:
#             nir_int = nir_src.read(1).astype('float32')
#             nir = (nir_int * scale_factor) + offset
#             if nir_src.nodata is not None:
#                 nir[nir_int == nir_src.nodata] = np.nan
        
#         np.seterr(divide='ignore', invalid='ignore')
#         numerator = nir - red
#         denominator = nir + red
#         ndvi = numerator / denominator
        
#         output_nodata = -9999.0
#         ndvi[np.isinf(ndvi)] = output_nodata
#         ndvi[np.isnan(ndvi)] = output_nodata
#         ndvi[denominator == 0] = output_nodata
        
#         valid_ndvi_mask = (ndvi >= -1) & (ndvi <= 1)
#         ndvi[~valid_ndvi_mask & (ndvi != output_nodata)] = output_nodata

#         profile = red_profile
#         profile.update(
#             dtype=rasterio.float32,
#             count=1,
#             compress='lzw',
#             nodata=output_nodata
#         )
        
#         with rasterio.open(output_file_path, 'w', **profile) as dst:
#             dst.write(ndvi.astype(rasterio.float32), 1)
            
#         print(f"Successfully calculated NDVI and saved to: {output_file_path}")

#     except Exception as e:
#         print(f"Error processing {os.path.basename(red_file_path)} or {os.path.basename(nir_file_path)}: {e}")

# def find_band_pairs_custom(input_dir, 
#                            red_filename_keyword="Red_band", 
#                            nir_filename_keyword="Nir_band",
#                            red_band_id_suffix="_SR_B4", 
#                            nir_band_id_suffix="_SR_B5",
#                            file_extension=".TIF"):
#     """
#     Finds pairs of Red and NIR band files based on custom keywords, 
#     scene IDs in parentheses, and band identifier suffixes.
#     """
#     pairs = []
#     # Regex to extract the scene ID like (147-041) from filenames
#     # It looks for content within parentheses: \( (.*?) \)
#     scene_id_regex = re.compile(r'\((.*?)\)') # (.*?) is a non-greedy match

#     potential_files = {} # Dictionary to store files found, keyed by scene_id

#     # Search recursively for TIF files (case-insensitive extension)
#     search_pattern_lower = os.path.join(input_dir, '**', f'*{file_extension.lower()}')
#     search_pattern_upper = os.path.join(input_dir, '**', f'*{file_extension.upper()}')
    
#     all_tif_files = glob.glob(search_pattern_lower, recursive=True) + \
#                     glob.glob(search_pattern_upper, recursive=True)
#     all_tif_files = list(set(all_tif_files)) # Remove duplicates if any

#     print(f"Found {len(all_tif_files)} files with extension '{file_extension}' in '{input_dir}' (and subdirectories).")
#     if not all_tif_files:
#         return pairs

#     for f_path in all_tif_files:
#         filename = os.path.basename(f_path)
        
#         # Try to extract scene_id (content within parentheses)
#         scene_id_match = scene_id_regex.search(filename)
#         if scene_id_match:
#             scene_id = scene_id_match.group(1) # e.g., "147-041"
            
#             if scene_id not in potential_files:
#                 potential_files[scene_id] = {}
            
#             # Check if it's a Red band
#             if red_filename_keyword in filename and filename.endswith(red_band_id_suffix + file_extension.upper()) \
#             or red_filename_keyword in filename and filename.endswith(red_band_id_suffix + file_extension.lower()):
#                 if 'red' in potential_files[scene_id]:
#                     print(f"Warning: Multiple Red files found for scene_id ({scene_id}). Overwriting {potential_files[scene_id]['red']} with {f_path}")
#                 potential_files[scene_id]['red'] = f_path
            
#             # Check if it's a NIR band
#             elif nir_filename_keyword in filename and filename.endswith(nir_band_id_suffix + file_extension.upper()) \
#             or nir_filename_keyword in filename and filename.endswith(nir_band_id_suffix + file_extension.lower()):
#                 if 'nir' in potential_files[scene_id]:
#                     print(f"Warning: Multiple NIR files found for scene_id ({scene_id}). Overwriting {potential_files[scene_id]['nir']} with {f_path}")
#                 potential_files[scene_id]['nir'] = f_path
#         # else:
#             # print(f"Debug: Could not extract scene ID from filename: {filename}")


#     # Now form pairs from the collected potential files
#     for scene_id, bands in potential_files.items():
#         if 'red' in bands and 'nir' in bands:
#             pairs.append((bands['red'], bands['nir']))
#             # print(f"Debug: Found pair for scene_id ({scene_id}): R={bands['red']}, N={bands['nir']}")
#         else:
#             print(f"Warning: Missing Red or NIR band for scene_id ({scene_id}). Found: {bands}")
            
#     return pairs

# # --- MAIN SCRIPT EXECUTION ---
# if __name__ == "__main__":
#     # --- USER: SET YOUR PATHS AND FILE NAMING CONVENTIONS HERE ---
#     landsat_input_directory = "C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATADATA/LANDSAT/NDVI"
#     ndvi_output_directory = ""C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATADATA/LANDSAT/NDVI/NDVI_OUTPUT"
    
#     # Keywords and suffixes based on your filenames like "Red_band(147-041)_SR_B4.TIF"
#     # Ensure these match your *actual* filenames precisely.
#     red_filename_keyword = "Red_band"
#     nir_filename_keyword = "Nir_band"
#     red_band_id_suffix = "_SR_B4"    # The part just before the .TIF extension for Red
#     nir_band_id_suffix = "_SR_B5"    # The part just before the .TIF extension for NIR
#     file_extension = ".TIF"          # Or ".tif" if your files use lowercase
#     # --- END OF USER SETTINGS ---

#     # Create output directory if it doesn't exist
#     if not os.path.exists(ndvi_output_directory):
#         os.makedirs(ndvi_output_directory)
#         print(f"Created output directory: {ndvi_output_directory}")

#     # Find all Red and NIR band pairs based on the custom naming convention
#     band_pairs = find_band_pairs_custom(landsat_input_directory, 
#                                        red_filename_keyword, 
#                                        nir_filename_keyword,
#                                        red_band_id_suffix, 
#                                        nir_band_id_suffix,
#                                        file_extension)

#     if not band_pairs:
#         print(f"\nNo Red and NIR band pairs found in '{landsat_input_directory}'.")
#         print("Please check:")
#         print("1. Your `landsat_input_directory` path.")
#         print("2. Your actual filenames and ensure they consistently follow the pattern:")
#         print(f"   '{red_filename_keyword}(SCENE_ID){red_band_id_suffix}{file_extension}' for Red bands")
#         print(f"   '{nir_filename_keyword}(SCENE_ID){nir_band_id_suffix}{file_extension}' for NIR bands")
#         print(f"   (e.g., Red_band(123-456)_SR_B4.TIF and Nir_band(123-456)_SR_B5.TIF)")
#         print("3. Correct any typos in your filenames (like the extra dot you mentioned).")
#         print("4. Ensure the `file_extension` variable matches your files (.TIF or .tif).")
#     else:
#         print(f"\nFound {len(band_pairs)} Red/NIR band pairs to process.")

#         for i, (red_path, nir_path) in enumerate(band_pairs):
#             print(f"\nProcessing pair {i+1}/{len(band_pairs)}:")
#             # print(f"  Red: {red_path}") # Already printed by find_band_pairs_custom if debug is on
#             # print(f"  NIR: {nir_path}")
            
#             # Define output filename for the NDVI raster
#             # Extracts the scene_id and common parts for a more descriptive output name
#             red_basename = os.path.basename(red_path)
#             scene_id_match = re.search(r'\((.*?)\)', red_basename)
#             scene_id_str = scene_id_match.group(1) if scene_id_match else "UNKNOWN_SCENE"
            
#             output_ndvi_file = os.path.join(ndvi_output_directory, f"NDVI_({scene_id_str}).TIF")
            
#             calculate_ndvi(red_path, nir_path, output_ndvi_file)
            
#     print("\nNDVI processing complete.")
# Out:
#   Cell In[1], line 134
#     ndvi_output_directory = ""C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATADATA/LANDSAT/NDVI/NDVI_OUTPUT"
#                               ^
# SyntaxError: invalid syntax

# %%
import os
import glob
import rasterio
import numpy as np
import re # For using regular expressions to extract scene IDs

def calculate_ndvi(red_file_path, nir_file_path, output_file_path):
    """
    Calculates NDVI from Red and NIR band files and saves the result.
    (This function remains largely the same as the previous rasterio version,
     assuming input Red and NIR bands need scaling if they are raw Landsat values)
    """
    try:
        # --- Define Landsat Collection 2 Level 2 scaling factors ---
        # If your "Red_band(...)" files are already reflectance (0-1),
        # set scale_factor = 1.0 and offset = 0.0
        # If they are raw scaled integers from Landsat SR products:
        # These are typical scaling factors for Landsat Level-2 Surface Reflectance (SR) products.
        # If you downloaded Level-1 data, these might convert to TOA reflectance, not surface reflectance.
        # For Level-1 data, further atmospheric correction (e.g., using L8SR, Sen2Cor in SNAP, etc.)
        # is usually needed for accurate surface reflectance and NDVI.
        scale_factor = 0.0000275
        offset = -0.2
        
        with rasterio.open(red_file_path) as red_src:
            red_profile = red_src.profile
            red_int = red_src.read(1).astype('float32')
            red = (red_int * scale_factor) + offset
            if red_src.nodata is not None:
                red[red_int == red_src.nodata] = np.nan

        with rasterio.open(nir_file_path) as nir_src:
            nir_int = nir_src.read(1).astype('float32')
            nir = (nir_int * scale_factor) + offset
            if nir_src.nodata is not None:
                nir[nir_int == nir_src.nodata] = np.nan
        
        np.seterr(divide='ignore', invalid='ignore')
        numerator = nir - red
        denominator = nir + red
        ndvi = numerator / denominator
        
        output_nodata = -9999.0
        ndvi[np.isinf(ndvi)] = output_nodata
        ndvi[np.isnan(ndvi)] = output_nodata
        ndvi[denominator == 0] = output_nodata
        
        valid_ndvi_mask = (ndvi >= -1) & (ndvi <= 1)
        ndvi[~valid_ndvi_mask & (ndvi != output_nodata)] = output_nodata

        profile = red_profile
        profile.update(
            dtype=rasterio.float32,
            count=1,
            compress='lzw',
            nodata=output_nodata
        )
        
        with rasterio.open(output_file_path, 'w', **profile) as dst:
            dst.write(ndvi.astype(rasterio.float32), 1)
            
        print(f"Successfully calculated NDVI and saved to: {output_file_path}")

    except Exception as e:
        print(f"Error processing {os.path.basename(red_file_path)} or {os.path.basename(nir_file_path)}: {e}")

def find_band_pairs_custom(input_dir, 
                           red_filename_keyword="", # Not directly used for regex but can be left.
                           nir_filename_keyword="", # Not directly used for regex but can be left.
                           red_band_id_suffix="_B4", 
                           nir_band_id_suffix="_B5",
                           file_extension=".TIF"):
    """
    Finds pairs of Red and NIR band files based on common unique scene IDs
    and band identifier suffixes.
    This version is adapted for standard Landsat 8/9 Level-1 naming conventions
    like 'LC09_L1TP_148043_20240211_20240211_02_T1_B4.TIF'.
    """
    pairs = []
    # MODIFIED REGEX: Captures the unique scene ID part (everything before the band suffix and extension)
    # Example: 'LC09_L1TP_148043_20240211_20240211_02_T1'
    # This regex assumes the unique scene ID is followed by _B4.TIF or _B5.TIF
    scene_id_regex = re.compile(r'(.*?)_B[45]\.TIF$', re.IGNORECASE) 

    potential_files = {} # Dictionary to store files found, keyed by scene_id

    # Search recursively for TIF files (case-insensitive extension)
    search_pattern_lower = os.path.join(input_dir, '**', f'*{file_extension.lower()}')
    search_pattern_upper = os.path.join(input_dir, '**', f'*{file_extension.upper()}')
    
    all_tif_files = glob.glob(search_pattern_lower, recursive=True) + \
                    glob.glob(search_pattern_upper, recursive=True)
    all_tif_files = list(set(all_tif_files)) # Remove duplicates if any

    print(f"Found {len(all_tif_files)} files with extension '{file_extension}' in '{input_dir}' (and subdirectories).")
    if not all_tif_files:
        return pairs

    for f_path in all_tif_files:
        filename = os.path.basename(f_path)
        
        # Try to extract scene_id using the modified regex
        scene_id_match = scene_id_regex.search(filename)
        if scene_id_match:
            scene_id = scene_id_match.group(1) # This will capture the unique part like "LC09_L1TP_148043_20240211_20240211_02_T1"
            
            if scene_id not in potential_files:
                potential_files[scene_id] = {}
            
            # MODIFIED LOGIC: Check if it's a Red band by its specific suffix
            if filename.endswith(red_band_id_suffix + file_extension.upper()) or filename.endswith(red_band_id_suffix + file_extension.lower()):
                if 'red' in potential_files[scene_id]:
                    print(f"Warning: Multiple Red files found for scene_id ({scene_id}). Overwriting {potential_files[scene_id]['red']} with {f_path}")
                potential_files[scene_id]['red'] = f_path
            
            # MODIFIED LOGIC: Check if it's a NIR band by its specific suffix
            elif filename.endswith(nir_band_id_suffix + file_extension.upper()) or filename.endswith(nir_band_id_suffix + file_extension.lower()):
                if 'nir' in potential_files[scene_id]:
                    print(f"Warning: Multiple NIR files found for scene_id ({scene_id}). Overwriting {potential_files[scene_id]['nir']} with {f_path}")
                potential_files[scene_id]['nir'] = f_path
        # else:
            # print(f"Debug: Could not extract scene ID from filename: {filename}") # Uncomment for debugging

    # Now form pairs from the collected potential files
    for scene_id, bands in potential_files.items():
        if 'red' in bands and 'nir' in bands:
            pairs.append((bands['red'], bands['nir']))
            # print(f"Debug: Found pair for scene_id ({scene_id}): R={bands['red']}, N={bands['nir']}") # Uncomment for debugging
        else:
            print(f"Warning: Missing Red or NIR band for scene_id ({scene_id}). Found: {bands}")
            
    return pairs

# --- MAIN SCRIPT EXECUTION ---
if __name__ == "__main__":
    # --- USER: SET YOUR PATHS AND FILE NAMING CONVENTIONS HERE ---
    
    # 1. Path to the root folder containing your Red_bands and NIR_bands subfolders
    # Based on your input: C:\Users\Lenovo\Documents\Dam_Suitability_Analysis\
    landsat_input_directory = "C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI" 

    # 2. Path to save the calculated NDVI rasters (individual scenes)
    # The script will create this subfolder if it doesn't exist
    ndvi_output_directory = "C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI/NDVI_OUTPUT" 
    
    # 3. Keywords and suffixes based on your *actual* Landsat Level-1 filenames
    # Example: LC09_L1TP_148043_20240211_20240211_02_T1_B4.TIF
    # The 'keyword' here is essentially a part of the filename used to distinguish bands,
    # but the primary identification is now done by the _B4 and _B5 suffixes.
    red_filename_keyword = "_B4"    # Part that uniquely identifies Red band (e.g., '_B4')
    nir_filename_keyword = "_B5"    # Part that uniquely identifies NIR band (e.g., '_B5')
    red_band_id_suffix = "_B4"      # The exact suffix before .TIF for Red band
    nir_band_id_suffix = "_B5"      # The exact suffix before .TIF for NIR band
    file_extension = ".TIF"         # Or ".tif" if your files use lowercase

    # --- END OF USER SETTINGS ---

    # Create output directory if it doesn't exist
    if not os.path.exists(ndvi_output_directory):
        os.makedirs(ndvi_output_directory)
        print(f"Created output directory: {ndvi_output_directory}")

    # Find all Red and NIR band pairs based on the custom naming convention
    band_pairs = find_band_pairs_custom(landsat_input_directory, 
                                       red_filename_keyword, 
                                       nir_filename_keyword,
                                       red_band_id_suffix, 
                                       nir_band_id_suffix,
                                       file_extension)

    if not band_pairs:
        print(f"\nNo Red and NIR band pairs found in '{landsat_input_directory}'.")
        print("Please ensure your `landsat_input_directory` is correct and contains `Red_bands` and `NIR_bands` subfolders with the appropriate `.TIF` files.")
        print("Also, double-check that your filenames match the expected suffixes like '_B4.TIF' and '_B5.TIF'.")
    else:
        print(f"\nFound {len(band_pairs)} Red/NIR band pairs to process.")

        for i, (red_path, nir_path) in enumerate(band_pairs):
            print(f"\nProcessing pair {i+1}/{len(band_pairs)}:")
            
            # Define output filename for the NDVI raster
            # This extracts the unique part of the filename before the _B4.TIF or _B5.TIF suffix
            red_basename = os.path.basename(red_path)
            # Use the same regex as in find_band_pairs_custom to extract the scene_id
            scene_id_match = re.search(r'(.*?)_B[45]\.TIF$', red_basename, re.IGNORECASE)
            scene_id_str = scene_id_match.group(1) if scene_id_match else "UNKNOWN_SCENE"
            
            output_ndvi_file = os.path.join(ndvi_output_directory, f"NDVI_({scene_id_str}).TIF")
            
            calculate_ndvi(red_path, nir_path, output_ndvi_file)
            
    print("\nNDVI processing complete.")
# Out:
# Found 2 files with extension '.TIF' in 'C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI' (and subdirectories).
#
# Found 1 Red/NIR band pairs to process.
#
# Processing pair 1/1:
# Successfully calculated NDVI and saved to: C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI/NDVI_OUTPUT\NDVI_(LC08_L1TP_147048_20241228_20250104_02_T1).TIF
#
# NDVI processing complete.

# %%
import os
import glob
import rasterio
import numpy as np
import re # For using regular expressions to extract scene IDs

def calculate_ndvi(red_file_path, nir_file_path, output_file_path):
    """
    Calculates NDVI from Red and NIR band files and saves the result.
    (This function remains largely the same as the previous rasterio version,
     assuming input Red and NIR bands need scaling if they are raw Landsat values)
    """
    try:
        # --- Define Landsat Collection 2 Level 2 scaling factors ---
        # If your "Red_band(...)" files are already reflectance (0-1),
        # set scale_factor = 1.0 and offset = 0.0
        # If they are raw scaled integers from Landsat SR products:
        # These are typical scaling factors for Landsat Level-2 Surface Reflectance (SR) products.
        # If you downloaded Level-1 data, these might convert to TOA reflectance, not surface reflectance.
        # For Level-1 data, further atmospheric correction (e.g., using L8SR, Sen2Cor in SNAP, etc.)
        # is usually needed for accurate surface reflectance and NDVI.
        scale_factor = 0.0000275
        offset = -0.2
        
        with rasterio.open(red_file_path) as red_src:
            red_profile = red_src.profile
            red_int = red_src.read(1).astype('float32')
            red = (red_int * scale_factor) + offset
            if red_src.nodata is not None:
                red[red_int == red_src.nodata] = np.nan

        with rasterio.open(nir_file_path) as nir_src:
            nir_int = nir_src.read(1).astype('float32')
            nir = (nir_int * scale_factor) + offset
            if nir_src.nodata is not None:
                nir[nir_int == nir_src.nodata] = np.nan
        
        np.seterr(divide='ignore', invalid='ignore')
        numerator = nir - red
        denominator = nir + red
        ndvi = numerator / denominator
        
        output_nodata = -9999.0
        ndvi[np.isinf(ndvi)] = output_nodata
        ndvi[np.isnan(ndvi)] = output_nodata
        ndvi[denominator == 0] = output_nodata
        
        valid_ndvi_mask = (ndvi >= -1) & (ndvi <= 1)
        ndvi[~valid_ndvi_mask & (ndvi != output_nodata)] = output_nodata

        profile = red_profile
        profile.update(
            dtype=rasterio.float32,
            count=1,
            compress='lzw',
            nodata=output_nodata
        )
        
        with rasterio.open(output_file_path, 'w', **profile) as dst:
            dst.write(ndvi.astype(rasterio.float32), 1)
            
        print(f"Successfully calculated NDVI and saved to: {output_file_path}")

    except Exception as e:
        print(f"Error processing {os.path.basename(red_file_path)} or {os.path.basename(nir_file_path)}: {e}")

def find_band_pairs_custom(input_dir, 
                           red_filename_keyword="", # Not directly used for regex but can be left.
                           nir_filename_keyword="", # Not directly used for regex but can be left.
                           red_band_id_suffix="_B4", 
                           nir_band_id_suffix="_B5",
                           file_extension=".tif"):
    """
    Finds pairs of Red and NIR band files based on common unique scene IDs
    and band identifier suffixes.
    This version is adapted for standard Landsat 8/9 Level-1 naming conventions
    like 'LC09_L1TP_148043_20240211_20240211_02_T1_B4.TIF'.
    """
    pairs = []
    # MODIFIED REGEX: Captures the unique scene ID part (everything before the band suffix and extension)
    # Example: 'LC09_L1TP_148043_20240211_20240211_02_T1'
    # This regex assumes the unique scene ID is followed by _B4.TIF or _B5.TIF
    scene_id_regex = re.compile(r'(.*?)_B[45]\.' + re.escape(file_extension) + '$', re.IGNORECASE) 

    potential_files = {} # Dictionary to store files found, keyed by scene_id

    # Search recursively for TIF files (case-insensitive extension)
    # This searches in subfolders like Red_bands/ and NIR_bands/
    search_pattern_lower = os.path.join(input_dir, '**', f'*{file_extension.lower()}')
    search_pattern_upper = os.path.join(input_dir, '**', f'*{file_extension.upper()}')
    
    all_tif_files = glob.glob(search_pattern_lower, recursive=True) + \
                    glob.glob(search_pattern_upper, recursive=True)
    all_tif_files = list(set(all_tif_files)) # Remove duplicates if any

    print(f"Found {len(all_tif_files)} files with extension '{file_extension}' in '{input_dir}' (and subdirectories).")
    if not all_tif_files:
        return pairs

    for f_path in all_tif_files:
        filename = os.path.basename(f_path)
        
        # Try to extract scene_id using the modified regex
        scene_id_match = scene_id_regex.search(filename)
        if scene_id_match:
            scene_id = scene_id_match.group(1) # This will capture the unique part like "LC09_L1TP_148043_20240211_20240211_02_T1"
            
            if scene_id not in potential_files:
                potential_files[scene_id] = {}
            
            # MODIFIED LOGIC: Check if it's a Red band by its specific suffix
            if filename.endswith(red_band_id_suffix + file_extension.upper()) or filename.endswith(red_band_id_suffix + file_extension.lower()):
                if 'red' in potential_files[scene_id]:
                    print(f"Warning: Multiple Red files found for scene_id ({scene_id}). Overwriting {potential_files[scene_id]['red']} with {f_path}")
                potential_files[scene_id]['red'] = f_path
            
            # MODIFIED LOGIC: Check if it's a NIR band by its specific suffix
            elif filename.endswith(nir_band_id_suffix + file_extension.upper()) or filename.endswith(nir_band_id_suffix + file_extension.lower()):
                if 'nir' in potential_files[scene_id]:
                    print(f"Warning: Multiple NIR files found for scene_id ({scene_id}). Overwriting {potential_files[scene_id]['nir']} with {f_path}")
                potential_files[scene_id]['nir'] = f_path
        # else:
            # print(f"Debug: Could not extract scene ID from filename: {filename}") # Uncomment for debugging

    # Now form pairs from the collected potential files
    for scene_id, bands in potential_files.items():
        if 'red' in bands and 'nir' in bands:
            pairs.append((bands['red'], bands['nir']))
            # print(f"Debug: Found pair for scene_id ({scene_id}): R={bands['red']}, N={bands['nir']}") # Uncomment for debugging
        else:
            print(f"Warning: Missing Red or NIR band for scene_id ({scene_id}). Found: {bands}")
            
    return pairs

# --- MAIN SCRIPT EXECUTION ---
if __name__ == "__main__":
    # --- USER: SET YOUR PATHS AND FILE NAMING CONVENTIONS HERE ---
    
    # 1. Path to the root folder containing your Red_bands and NIR_bands subfolders
    # This path should be: Dam_Suitability_Analysis/Data/Landsat_Raw/
    # The find_band_pairs_custom function will search recursively within this directory.
    landsat_input_directory = "C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI" 

    # 2. Path to save the calculated NDVI rasters (individual scenes)
    # This path should be: Dam_Suitability_Analysis/Data/Processed_Rasters/NDVI_Individual/
    ndvi_output_directory = "C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI/NDVI_OUTPUT" 
    
    # 3. Keywords and suffixes based on your *actual* Landsat Level-1 filenames
    # Example: LC09_L1TP_148043_20240211_20240211_02_T1_B4.TIF
    red_filename_keyword = "_B4"    # Part that uniquely identifies Red band (e.g., '_B4')
    nir_filename_keyword = "_B5"    # Part that uniquely identifies NIR band (e.g., '_B5')
    red_band_id_suffix = "_B4"      # The exact suffix before .TIF for Red band
    nir_band_id_suffix = "_B5"      # The exact suffix before .TIF for NIR band
    file_extension = ".tif"         # Or ".tif" if your files use lowercase

    # --- END OF USER SETTINGS ---

    # Create output directory if it doesn't exist
    if not os.path.exists(ndvi_output_directory):
        os.makedirs(ndvi_output_directory)
        print(f"Created output directory: {ndvi_output_directory}")

    # Find all Red and NIR band pairs based on the custom naming convention
    band_pairs = find_band_pairs_custom(landsat_input_directory, 
                                       red_filename_keyword, 
                                       nir_filename_keyword,
                                       red_band_id_suffix, 
                                       nir_band_id_suffix,
                                       file_extension)

    if not band_pairs:
        print(f"\nNo Red and NIR band pairs found in '{landsat_input_directory}'.")
        print("Please ensure your `landsat_input_directory` is correct and contains `Red_bands` and `NIR_bands` subfolders with the appropriate `.TIF` files.")
        print("Also, double-check that your filenames match the expected suffixes like '_B4.TIF' and '_B5.TIF'.")
    else:
        print(f"\nFound {len(band_pairs)} Red/NIR band pairs to process.")

        for i, (red_path, nir_path) in enumerate(band_pairs):
            print(f"\nProcessing pair {i+1}/{len(band_pairs)}:")
            
            # Define output filename for the NDVI raster
            # This extracts the unique part of the filename before the _B4.TIF or _B5.TIF suffix
            red_basename = os.path.basename(red_path)
            # Use the same regex as in find_band_pairs_custom to extract the scene_id
            scene_id_match = re.search(r'(.*?)_B[45]\.' + re.escape(file_extension) + '$', red_basename, re.IGNORECASE)
            scene_id_str = scene_id_match.group(1) if scene_id_match else "UNKNOWN_SCENE"
            
            output_ndvi_file = os.path.join(ndvi_output_directory, f"NDVI_({scene_id_str}).TIF")
            
            calculate_ndvi(red_path, nir_path, output_ndvi_file)
            
    print("\nNDVI processing complete.")
# Out:
# Found 3 files with extension '.tif' in 'C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI' (and subdirectories).
#
# No Red and NIR band pairs found in 'C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI'.
# Please ensure your `landsat_input_directory` is correct and contains `Red_bands` and `NIR_bands` subfolders with the appropriate `.TIF` files.
# Also, double-check that your filenames match the expected suffixes like '_B4.TIF' and '_B5.TIF'.
#
# NDVI processing complete.

# %%
import os
import glob
import rasterio
import numpy as np
import re # For using regular expressions to extract scene IDs

def calculate_ndvi(red_file_path, nir_file_path, output_file_path):
    """
    Calculates NDVI from Red and NIR band files and saves the result.
    (This function remains largely the same as the previous rasterio version,
     assuming input Red and NIR bands need scaling if they are raw Landsat values)
    """
    try:
        # --- Define Landsat Collection 2 Level 2 scaling factors ---
        # If your "Red_band(...)" files are already reflectance (0-1),
        # set scale_factor = 1.0 and offset = 0.0
        # If they are raw scaled integers from Landsat SR products:
        # These are typical scaling factors for Landsat Level-2 Surface Reflectance (SR) products.
        # If you downloaded Level-1 data, these might convert to TOA reflectance, not surface reflectance.
        # For Level-1 data, further atmospheric correction (e.g., using L8SR, Sen2Cor in SNAP, etc.)
        # is usually needed for accurate surface reflectance and NDVI.
        scale_factor = 0.0000275
        offset = -0.2
        
        with rasterio.open(red_file_path) as red_src:
            red_profile = red_src.profile
            red_int = red_src.read(1).astype('float32')
            red = (red_int * scale_factor) + offset
            if red_src.nodata is not None:
                red[red_int == red_src.nodata] = np.nan

        with rasterio.open(nir_file_path) as nir_src:
            nir_int = nir_src.read(1).astype('float32')
            nir = (nir_int * scale_factor) + offset
            if nir_src.nodata is not None:
                nir[nir_int == nir_src.nodata] = np.nan
        
        np.seterr(divide='ignore', invalid='ignore')
        numerator = nir - red
        denominator = nir + red
        ndvi = numerator / denominator
        
        output_nodata = -9999.0
        ndvi[np.isinf(ndvi)] = output_nodata
        ndvi[np.isnan(ndvi)] = output_nodata
        ndvi[denominator == 0] = output_nodata
        
        valid_ndvi_mask = (ndvi >= -1) & (ndvi <= 1)
        ndvi[~valid_ndvi_mask & (ndvi != output_nodata)] = output_nodata

        profile = red_profile
        profile.update(
            dtype=rasterio.float32,
            count=1,
            compress='lzw',
            nodata=output_nodata
        )
        
        with rasterio.open(output_file_path, 'w', **profile) as dst:
            dst.write(ndvi.astype(rasterio.float32), 1)
            
        print(f"Successfully calculated NDVI and saved to: {output_file_path}")

    except Exception as e:
        print(f"Error processing {os.path.basename(red_file_path)} or {os.path.basename(nir_file_path)}: {e}")

def find_band_pairs_custom(input_dir, 
                           red_filename_keyword="", # Not directly used for regex but can be left.
                           nir_filename_keyword="", # Not directly used for regex but can be left.
                           red_band_id_suffix="_B4", 
                           nir_band_id_suffix="_B5",
                           file_extension=".TIF"):
    """
    Finds pairs of Red and NIR band files based on common unique scene IDs
    and band identifier suffixes.
    This version is adapted for standard Landsat 8/9 Level-1 naming conventions
    like 'LC09_L1TP_148043_20240211_20240211_02_T1_B4.TIF'.
    """
    pairs = []
    # MODIFIED REGEX: Captures the unique scene ID part (everything before the band suffix and extension)
    # Example: 'LC09_L1TP_148043_20240211_20240211_02_T1'
    # This regex assumes the unique scene ID is followed by _B4.TIF or _B5.TIF
    scene_id_regex = re.compile(r'(.*?)_B[45]\.' + re.escape(file_extension) + '$', re.IGNORECASE) 

    potential_files = {} # Dictionary to store files found, keyed by scene_id

    # Search recursively for TIF files (case-insensitive extension)
    # This searches in subfolders like Red_bands/ and NIR_bands/
    search_pattern_lower = os.path.join(input_dir, '**', f'*{file_extension.lower()}')
    search_pattern_upper = os.path.join(input_dir, '**', f'*{file_extension.upper()}')
    
    all_tif_files = glob.glob(search_pattern_lower, recursive=True) + \
                    glob.glob(search_pattern_upper, recursive=True)
    all_tif_files = list(set(all_tif_files)) # Remove duplicates if any

    print(f"Found {len(all_tif_files)} files with extension '{file_extension}' in '{input_dir}' (and subdirectories).")
    if not all_tif_files:
        return pairs

    for f_path in all_tif_files:
        filename = os.path.basename(f_path)
        
        # Try to extract scene_id using the modified regex
        scene_id_match = scene_id_regex.search(filename)
        if scene_id_match:
            scene_id = scene_id_match.group(1) # This will capture the unique part like "LC09_L1TP_148043_20240211_20240211_02_T1"
            
            if scene_id not in potential_files:
                potential_files[scene_id] = {}
            
            # MODIFIED LOGIC: Check if it's a Red band by its specific suffix
            if filename.endswith(red_band_id_suffix + file_extension.upper()) or filename.endswith(red_band_id_suffix + file_extension.lower()):
                potential_files[scene_id]['red'] = f_path
            
            # MODIFIED LOGIC: Check if it's a NIR band by its specific suffix
            elif filename.endswith(nir_band_id_suffix + file_extension.upper()) or filename.endswith(nir_band_id_suffix + file_extension.lower()):
                potential_files[scene_id]['nir'] = f_path

    # Now form pairs from the collected potential files
    for scene_id, bands in potential_files.items():
        if 'red' in bands and 'nir' in bands:
            pairs.append((bands['red'], bands['nir']))
        else:
            print(f"Warning: Missing Red or NIR band for scene_id ({scene_id}). Found: {bands}")
            
    return pairs

# --- MAIN SCRIPT EXECUTION ---
if __name__ == "__main__":
    # --- USER: SET YOUR PATHS AND FILE NAMING CONVENTIONS HERE ---
    
    # 1. Path to the root folder containing your Red_bands and NIR_bands subfolders
    # This path should be: Dam_Suitability_Analysis/Data/Landsat_Raw/
    # The find_band_pairs_custom function will search recursively within this directory.
    landsat_input_directory = "C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI" 

    # 2. Path to save the calculated NDVI rasters (individual scenes)
    # This path should be: Dam_Suitability_Analysis/Data/Processed_Rasters/NDVI_Individual/
    ndvi_output_directory = "C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI" 
    
    # 3. Keywords and suffixes based on your *actual* Landsat Level-1 filenames
    # Example: LC09_L1TP_148043_20240211_20240211_02_T1_B4.TIF
    red_filename_keyword = "_B4"    # Part that uniquely identifies Red band (e.g., '_B4')
    nir_filename_keyword = "_B5"    # Part that uniquely identifies NIR band (e.g., '_B5')
    red_band_id_suffix = "_B4"      # The exact suffix before .TIF for Red band
    nir_band_id_suffix = "_B5"      # The exact suffix before .TIF for NIR band
    file_extension = ".TIF"         # Or ".tif" if your files use lowercase

    # --- END OF USER SETTINGS ---

    # Create output directory if it doesn't exist
    if not os.path.exists(ndvi_output_directory):
        os.makedirs(ndvi_output_directory)
        print(f"Created output directory: {ndvi_output_directory}")

    # Find all Red and NIR band pairs based on the custom naming convention
    band_pairs = find_band_pairs_custom(landsat_input_directory, 
                                       red_filename_keyword, 
                                       nir_filename_keyword,
                                       red_band_id_suffix, 
                                       nir_band_id_suffix,
                                       file_extension)

    if not band_pairs:
        print(f"\nNo Red and NIR band pairs found in '{landsat_input_directory}'.")
        print("Please ensure your `landsat_input_directory` is correct and contains `Red_bands` and `NIR_bands` subfolders with the appropriate `.TIF` files.")
        print("Also, double-check that your filenames match the expected suffixes like '_B4.TIF' and '_B5.TIF'.")
    else:
        print(f"\nFound {len(band_pairs)} Red/NIR band pairs to process.")

        for i, (red_path, nir_path) in enumerate(band_pairs):
            print(f"\nProcessing pair {i+1}/{len(band_pairs)}:")
            
            # Define output filename for the NDVI raster
            # This extracts the unique part of the filename before the _B4.TIF or _B5.TIF suffix
            red_basename = os.path.basename(red_path)
            # Use the same regex as in find_band_pairs_custom to extract the scene_id
            scene_id_match = re.search(r'(.*?)_B[45]\.' + re.escape(file_extension) + '$', red_basename, re.IGNORECASE)
            scene_id_str = scene_id_match.group(1) if scene_id_match else "UNKNOWN_SCENE"
            
            output_ndvi_file = os.path.join(ndvi_output_directory, f"NDVI_({scene_id_str}).TIF")
            
            calculate_ndvi(red_path, nir_path, output_ndvi_file)
            
    print("\nNDVI processing complete.")
# Out:
# Found 3 files with extension '.TIF' in 'C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI' (and subdirectories).
#
# No Red and NIR band pairs found in 'C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI'.
# Please ensure your `landsat_input_directory` is correct and contains `Red_bands` and `NIR_bands` subfolders with the appropriate `.TIF` files.
# Also, double-check that your filenames match the expected suffixes like '_B4.TIF' and '_B5.TIF'.
#
# NDVI processing complete.

# %%
import os
import glob
import rasterio
import numpy as np
import re # For using regular expressions to extract scene IDs

def calculate_ndvi(red_file_path, nir_file_path, output_file_path):
    """
    Calculates NDVI from Red and NIR band files and saves the result.
    (This function remains largely the same as the previous rasterio version,
     assuming input Red and NIR bands need scaling if they are raw Landsat values)
    """
    try:
        # --- Define Landsat Collection 2 Level 2 scaling factors ---
        # If your "Red_band(...)" files are already reflectance (0-1),
        # set scale_factor = 1.0 and offset = 0.0
        # If they are raw scaled integers from Landsat SR products:
        # These are typical scaling factors for Landsat Level-2 Surface Reflectance (SR) products.
        # If you downloaded Level-1 data, these might convert to TOA reflectance, not surface reflectance.
        # For Level-1 data, further atmospheric correction (e.g., using L8SR, Sen2Cor in SNAP, etc.)
        # is usually needed for accurate surface reflectance and NDVI.
        scale_factor = 0.0000275
        offset = -0.2
        
        with rasterio.open(red_file_path) as red_src:
            red_profile = red_src.profile
            red_int = red_src.read(1).astype('float32')
            red = (red_int * scale_factor) + offset
            if red_src.nodata is not None:
                red[red_int == red_src.nodata] = np.nan

        with rasterio.open(nir_file_path) as nir_src:
            nir_int = nir_src.read(1).astype('float32')
            nir = (nir_int * scale_factor) + offset
            if nir_src.nodata is not None:
                nir[nir_int == nir_src.nodata] = np.nan
        
        np.seterr(divide='ignore', invalid='ignore')
        numerator = nir - red
        denominator = nir + red
        ndvi = numerator / denominator
        
        output_nodata = -9999.0
        ndvi[np.isinf(ndvi)] = output_nodata
        ndvi[np.isnan(ndvi)] = output_nodata
        ndvi[denominator == 0] = output_nodata
        
        valid_ndvi_mask = (ndvi >= -1) & (ndvi <= 1)
        ndvi[~valid_ndvi_mask & (ndvi != output_nodata)] = output_nodata

        profile = red_profile
        profile.update(
            dtype=rasterio.float32,
            count=1,
            compress='lzw',
            nodata=output_nodata
        )
        
        with rasterio.open(output_file_path, 'w', **profile) as dst:
            dst.write(ndvi.astype(rasterio.float32), 1)
            
        print(f"Successfully calculated NDVI and saved to: {output_file_path}")

    except Exception as e:
        print(f"Error processing {os.path.basename(red_file_path)} or {os.path.basename(nir_file_path)}: {e}")

def find_band_pairs_custom(input_dir, 
                           red_filename_keyword="", # Not directly used for regex but can be left.
                           nir_filename_keyword="", # Not directly used for regex but can be left.
                           red_band_id_suffix="_B4", 
                           nir_band_id_suffix="_B5",
                           file_extension=".TIF"):
    """
    Finds pairs of Red and NIR band files based on common unique scene IDs
    and band identifier suffixes.
    This version is adapted for standard Landsat 8/9 Level-1 naming conventions
    like 'LC09_L1TP_148043_20240211_20240211_02_T1_B4.TIF'.
    It explicitly looks for Red_bands/ and NIR_bands/ subfolders.
    """
    pairs = []
    
    # MODIFIED REGEX: Captures the unique scene ID part (everything before the band suffix and extension)
    scene_id_regex = re.compile(r'(.*?)_B[45]\.' + re.escape(file_extension) + '$', re.IGNORECASE) 

    potential_files = {} # Dictionary to store files found, keyed by scene_id

    # --- MODIFIED: Explicitly search in Red_bands and NIR_bands subfolders ---
    red_bands_dir = os.path.join(input_dir, 'Red_bands')
    nir_bands_dir = os.path.join(input_dir, 'NIR_bands')

    all_red_files = glob.glob(os.path.join(red_bands_dir, f'*{red_band_id_suffix}{file_extension.lower()}')) + \
                    glob.glob(os.path.join(red_bands_dir, f'*{red_band_id_suffix}{file_extension.upper()}'))
    
    all_nir_files = glob.glob(os.path.join(nir_bands_dir, f'*{nir_band_id_suffix}{file_extension.lower()}')) + \
                    glob.glob(os.path.join(nir_bands_dir, f'*{nir_band_id_suffix}{file_extension.upper()}'))

    all_tif_files = list(set(all_red_files + all_nir_files)) # Combine and remove duplicates

    print(f"Found {len(all_tif_files)} files with extension '{file_extension}' in '{input_dir}' (and subdirectories).")
    if not all_tif_files:
        return pairs

    for f_path in all_tif_files:
        filename = os.path.basename(f_path)
        
        scene_id_match = scene_id_regex.search(filename)
        if scene_id_match:
            scene_id = scene_id_match.group(1)
            
            if scene_id not in potential_files:
                potential_files[scene_id] = {}
            
            if filename.endswith(red_band_id_suffix + file_extension.upper()) or filename.endswith(red_band_id_suffix + file_extension.lower()):
                potential_files[scene_id]['red'] = f_path
            elif filename.endswith(nir_band_id_suffix + file_extension.upper()) or filename.endswith(nir_band_id_suffix + file_extension.lower()):
                potential_files[scene_id]['nir'] = f_path

    for scene_id, bands in potential_files.items():
        if 'red' in bands and 'nir' in bands:
            pairs.append((bands['red'], bands['nir']))
        else:
            print(f"Warning: Missing Red or NIR band for scene_id ({scene_id}). Found: {bands}")
            
    return pairs

# --- MAIN SCRIPT EXECUTION ---
if __name__ == "__main__":
    # --- USER: SET YOUR PATHS AND FILE NAMING CONVENTIONS HERE ---
    
    # 1. Path to the root folder containing your Red_bands and NIR_bands subfolders
    # This path should be: Dam_Suitability_Analysis/Data/Landsat_Raw/
    landsat_input_directory = "C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI" 

    # 2. Path to save the calculated NDVI rasters (individual scenes)
    # This path should be: Dam_Suitability_Analysis/Data/Processed_Rasters/NDVI_Individual/
    ndvi_output_directory = "C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI" 
    
    # 3. Keywords and suffixes based on your *actual* Landsat Level-1 filenames
    # Example: LC09_L1TP_148043_20240211_20240211_02_T1_B4.TIF
    red_filename_keyword = "_B4"    # Not directly used in modified glob, but kept for consistency
    nir_filename_keyword = "_B5"    # Not directly used in modified glob, but kept for consistency
    red_band_id_suffix = "_B4"      # The exact suffix before .TIF for Red band
    nir_band_id_suffix = "_B5"      # The exact suffix before .TIF for NIR band
    file_extension = ".TIF"         # Or ".tif" if your files use lowercase

    # --- END OF USER SETTINGS ---

    # Create output directory if it doesn't exist
    if not os.path.exists(ndvi_output_directory):
        os.makedirs(ndvi_output_directory)
        print(f"Created output directory: {ndvi_output_directory}")

    # Find all Red and NIR band pairs based on the custom naming convention
    band_pairs = find_band_pairs_custom(landsat_input_directory, 
                                       red_filename_keyword, 
                                       nir_filename_keyword,
                                       red_band_id_suffix, 
                                       nir_band_id_suffix,
                                       file_extension)

    if not band_pairs:
        print(f"\nNo Red and NIR band pairs found in '{landsat_input_directory}'.")
        print("Please ensure your `landsat_input_directory` is correct and contains `Red_bands` and `NIR_bands` subfolders with the appropriate `.TIF` files.")
        print("Also, double-check that your filenames match the expected suffixes like '_B4.TIF' and '_B5.TIF'.")
    else:
        print(f"\nFound {len(band_pairs)} Red/NIR band pairs to process.")

        for i, (red_path, nir_path) in enumerate(band_pairs):
            print(f"\nProcessing pair {i+1}/{len(band_pairs)}:")
            
            # Define output filename for the NDVI raster
            # This extracts the unique part of the filename before the _B4.TIF or _B5.TIF suffix
            red_basename = os.path.basename(red_path)
            # Use the same regex as in find_band_pairs_custom to extract the scene_id
            scene_id_match = re.search(r'(.*?)_B[45]\.' + re.escape(file_extension) + '$', red_basename, re.IGNORECASE)
            scene_id_str = scene_id_match.group(1) if scene_id_match else "UNKNOWN_SCENE"
            
            output_ndvi_file = os.path.join(ndvi_output_directory, f"NDVI_({scene_id_str}).TIF")
            
            calculate_ndvi(red_path, nir_path, output_ndvi_file)
            
    print("\nNDVI processing complete.")
# Out:
# Found 2 files with extension '.TIF' in 'C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI' (and subdirectories).
#
# No Red and NIR band pairs found in 'C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI'.
# Please ensure your `landsat_input_directory` is correct and contains `Red_bands` and `NIR_bands` subfolders with the appropriate `.TIF` files.
# Also, double-check that your filenames match the expected suffixes like '_B4.TIF' and '_B5.TIF'.
#
# NDVI processing complete.

# %%
import os
import glob
import rasterio
import numpy as np
import re # For using regular expressions to extract scene IDs

def calculate_ndvi(red_file_path, nir_file_path, output_file_path):
    """
    Calculates NDVI from Red and NIR band files and saves the result.
    """
    try:
        scale_factor = 0.0000275 # For Landsat Level-1 to TOA reflectance
        offset = -0.2
        
        with rasterio.open(red_file_path) as red_src:
            red_profile = red_src.profile
            red_int = red_src.read(1).astype('float32')
            red = (red_int * scale_factor) + offset
            if red_src.nodata is not None:
                red[red_int == red_src.nodata] = np.nan

        with rasterio.open(nir_file_path) as nir_src:
            nir_int = nir_src.read(1).astype('float32')
            nir = (nir_int * scale_factor) + offset
            if nir_src.nodata is not None:
                nir[nir_int == nir_src.nodata] = np.nan
        
        np.seterr(divide='ignore', invalid='ignore')
        numerator = nir - red
        denominator = nir + red
        ndvi = numerator / denominator
        
        output_nodata = -9999.0
        ndvi[np.isinf(ndvi)] = output_nodata
        ndvi[np.isnan(ndvi)] = output_nodata
        ndvi[denominator == 0] = output_nodata
        
        valid_ndvi_mask = (ndvi >= -1) & (ndvi <= 1)
        ndvi[~valid_ndvi_mask & (ndvi != output_nodata)] = output_nodata

        profile = red_profile
        profile.update(
            dtype=rasterio.float32,
            count=1,
            compress='lzw',
            nodata=output_nodata
        )
        
        with rasterio.open(output_file_path, 'w', **profile) as dst:
            dst.write(ndvi.astype(rasterio.float32), 1)
            
        print(f"Successfully calculated NDVI and saved to: {output_file_path}")

    except Exception as e:
        print(f"Error processing {os.path.basename(red_file_path)} or {os.path.basename(nir_file_path)}: {e}")

def find_band_pairs_custom(input_dir, 
                           red_filename_keyword="", # Not directly used for regex but can be left.
                           nir_filename_keyword="", # Not directly used for regex but can be left.
                           red_band_id_suffix="_B4", 
                           nir_band_id_suffix="_B5",
                           file_extension=".TIF"):
    """
    Finds pairs of Red and NIR band files based on common unique scene IDs
    and band identifier suffixes.
    It explicitly looks for Red_bands/ and NIR_bands/ subfolders within input_dir.
    """
    pairs = []
    
    scene_id_regex = re.compile(r'(.*?)_B[45]\.' + re.escape(file_extension) + '$', re.IGNORECASE) 

    potential_files = {} 

    # --- MODIFIED: Explicitly search in Red_bands and NIR_bands subfolders ---
    red_bands_dir = os.path.join(input_dir, 'Red_bands')
    nir_bands_dir = os.path.join(input_dir, 'NIR_bands')

    all_red_files = glob.glob(os.path.join(red_bands_dir, f'*{red_band_id_suffix}{file_extension.lower()}')) + \
                    glob.glob(os.path.join(red_bands_dir, f'*{red_band_id_suffix}{file_extension.upper()}'))
    
    all_nir_files = glob.glob(os.path.join(nir_bands_dir, f'*{nir_band_id_suffix}{file_extension.lower()}')) + \
                    glob.glob(os.path.join(nir_bands_dir, f'*{nir_band_id_suffix}{file_extension.upper()}'))

    all_tif_files = list(set(all_red_files + all_nir_files)) # Combine and remove duplicates

    print(f"Found {len(all_tif_files)} files with extension '{file_extension}' in '{input_dir}' (and its 'Red_bands'/'NIR_bands' subdirectories).")
    if not all_tif_files:
        return pairs

    for f_path in all_tif_files:
        filename = os.path.basename(f_path)
        
        scene_id_match = scene_id_regex.search(filename)
        if scene_id_match:
            scene_id = scene_id_match.group(1)
            
            if scene_id not in potential_files:
                potential_files[scene_id] = {}
            
            if filename.endswith(red_band_id_suffix + file_extension.upper()) or filename.endswith(red_band_id_suffix + file_extension.lower()):
                potential_files[scene_id]['red'] = f_path
            elif filename.endswith(nir_band_id_suffix + file_extension.upper()) or filename.endswith(nir_band_id_suffix + file_extension.lower()):
                potential_files[scene_id]['nir'] = f_path

    for scene_id, bands in potential_files.items():
        if 'red' in bands and 'nir' in bands:
            pairs.append((bands['red'], bands['nir']))
        else:
            print(f"Warning: Missing Red or NIR band for scene_id ({scene_id}). Found: {bands}")
            
    return pairs

# --- MAIN SCRIPT EXECUTION ---
if __name__ == "__main__":
    # --- USER: SET YOUR PATHS AND FILE NAMING CONVENTIONS HERE ---
    
    # 1. Path to the root folder containing your Red_bands and NIR_bands subfolders
    # This path MUST be the parent directory of 'Red_bands' and 'NIR_bands'.
    # Example: C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/Data/Landsat_Raw/
    landsat_input_directory = "C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI" 

    # 2. Path to save the calculated NDVI rasters (individual scenes)
    # This path should be: Dam_Suitability_Analysis/Data/Processed_Rasters/NDVI_Individual/
    ndvi_output_directory = "C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI" 
    
    # 3. Keywords and suffixes based on your *actual* Landsat Level-1 filenames
    # Example: LC09_L1TP_148043_20240211_20240211_02_T1_B4.TIF
    red_filename_keyword = "_B4"    
    nir_filename_keyword = "_B5"    
    red_band_id_suffix = "_B4"      
    nir_band_id_suffix = "_B5"      
    file_extension = ".TIF"         # Or ".tif" if your files use lowercase

    # --- END OF USER SETTINGS ---

    # Create output directory if it doesn't exist
    if not os.path.exists(ndvi_output_directory):
        os.makedirs(ndvi_output_directory)
        print(f"Created output directory: {ndvi_output_directory}")

    # Find all Red and NIR band pairs based on the custom naming convention
    band_pairs = find_band_pairs_custom(landsat_input_directory, 
                                       red_filename_keyword, 
                                       nir_filename_keyword,
                                       red_band_id_suffix, 
                                       nir_band_id_suffix,
                                       file_extension)

    if not band_pairs:
        print(f"\nNo Red and NIR band pairs found in '{landsat_input_directory}'.")
        print("Please ensure your `landsat_input_directory` is correct and contains `Red_bands` and `NIR_bands` subfolders with the appropriate `.TIF` files.")
        print("Also, double-check that your filenames match the expected suffixes like '_B4.TIF' and '_B5.TIF'.")
    else:
        print(f"\nFound {len(band_pairs)} Red/NIR band pairs to process.")

        for i, (red_path, nir_path) in enumerate(band_pairs):
            print(f"\nProcessing pair {i+1}/{len(band_pairs)}:")
            
            # Define output filename for the NDVI raster
            # This extracts the unique part of the filename before the _B4.TIF or _B5.TIF suffix
            red_basename = os.path.basename(red_path)
            scene_id_match = re.search(r'(.*?)_B[45]\.' + re.escape(file_extension) + '$', red_basename, re.IGNORECASE)
            scene_id_str = scene_id_match.group(1) if scene_id_match else "UNKNOWN_SCENE"
            
            output_ndvi_file = os.path.join(ndvi_output_directory, f"NDVI_({scene_id_str}).TIF")
            
            calculate_ndvi(red_path, nir_path, output_ndvi_file)
            
    print("\nNDVI processing complete.")
# Out:
# Found 2 files with extension '.TIF' in 'C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI' (and its 'Red_bands'/'NIR_bands' subdirectories).
#
# No Red and NIR band pairs found in 'C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI'.
# Please ensure your `landsat_input_directory` is correct and contains `Red_bands` and `NIR_bands` subfolders with the appropriate `.TIF` files.
# Also, double-check that your filenames match the expected suffixes like '_B4.TIF' and '_B5.TIF'.
#
# NDVI processing complete.

# %%
import os
import glob
import rasterio
import numpy as np
import re # For using regular expressions to extract scene IDs

def calculate_ndvi(red_file_path, nir_file_path, output_file_path):
    """
    Calculates NDVI from Red and NIR band files and saves the result.
    """
    try:
        scale_factor = 0.0000275 # For Landsat Level-1 to TOA reflectance
        offset = -0.2
        
        with rasterio.open(red_file_path) as red_src:
            red_profile = red_src.profile
            red_int = red_src.read(1).astype('float32')
            red = (red_int * scale_factor) + offset
            if red_src.nodata is not None:
                red[red_int == red_src.nodata] = np.nan

        with rasterio.open(nir_file_path) as nir_src:
            nir_int = nir_src.read(1).astype('float32')
            nir = (nir_int * scale_factor) + offset
            if nir_src.nodata is not None:
                nir[nir_int == nir_src.nodata] = np.nan
        
        np.seterr(divide='ignore', invalid='ignore')
        numerator = nir - red
        denominator = nir + red
        ndvi = numerator / denominator
        
        output_nodata = -9999.0
        ndvi[np.isinf(ndvi)] = output_nodata
        ndvi[np.isnan(ndvi)] = output_nodata
        ndvi[denominator == 0] = output_nodata
        
        valid_ndvi_mask = (ndvi >= -1) & (ndvi <= 1)
        ndvi[~valid_ndvi_mask & (ndvi != output_nodata)] = output_nodata

        profile = red_profile
        profile.update(
            dtype=rasterio.float32,
            count=1,
            compress='lzw',
            nodata=output_nodata
        )
        
        with rasterio.open(output_file_path, 'w', **profile) as dst:
            dst.write(ndvi.astype(rasterio.float32), 1)
            
        print(f"Successfully calculated NDVI and saved to: {output_file_path}")

    except Exception as e:
        print(f"Error processing {os.path.basename(red_file_path)} or {os.path.basename(nir_file_path)}: {e}")

def find_band_pairs_custom(input_dir, 
                           red_filename_keyword="", 
                           nir_filename_keyword="", 
                           red_band_id_suffix="_B4", 
                           nir_band_id_suffix="_B5",
                           file_extension=".TIF"):
    """
    Finds pairs of Red and NIR band files based on common unique scene IDs
    and band identifier suffixes.
    It explicitly looks for Red_bands/ and NIR_bands/ subfolders within input_dir.
    """
    pairs = []
    
    # MODIFIED REGEX: Make it more flexible. It captures everything before _B4 or _B5.
    # It assumes the unique scene ID is followed by _B4 or _B5, then anything, then the extension.
    # This should be more robust to minor variations in filename suffix before the extension.
    scene_id_regex = re.compile(r'(.*?)_B[45].*?\.' + re.escape(file_extension) + '$', re.IGNORECASE) 

    potential_files = {} 

    red_bands_dir = os.path.join(input_dir, 'Red_bands')
    nir_bands_dir = os.path.join(input_dir, 'NIR_bands')

    all_red_files = glob.glob(os.path.join(red_bands_dir, f'*{red_band_id_suffix}{file_extension.lower()}')) + \
                    glob.glob(os.path.join(red_bands_dir, f'*{red_band_id_suffix}{file_extension.upper()}'))
    
    all_nir_files = glob.glob(os.path.join(nir_bands_dir, f'*{nir_band_id_suffix}{file_extension.lower()}')) + \
                    glob.glob(os.path.join(nir_bands_dir, f'*{nir_band_id_suffix}{file_extension.upper()}'))

    all_tif_files = list(set(all_red_files + all_nir_files)) 

    print(f"Found {len(all_tif_files)} files with extension '{file_extension}' in '{input_dir}' (and its 'Red_bands'/'NIR_bands' subdirectories).")
    if not all_tif_files:
        return pairs

    for f_path in all_tif_files:
        filename = os.path.basename(f_path)
        print(f"DEBUG: Processing filename: {filename}") # DEBUG PRINT
        
        scene_id_match = scene_id_regex.search(filename)
        if scene_id_match:
            scene_id = scene_id_match.group(1)
            print(f"DEBUG: Extracted scene_id: {scene_id} from {filename}") # DEBUG PRINT
            
            if scene_id not in potential_files:
                potential_files[scene_id] = {}
            
            is_red = filename.endswith(red_band_id_suffix + file_extension.upper()) or filename.endswith(red_band_id_suffix + file_extension.lower())
            is_nir = filename.endswith(nir_band_id_suffix + file_extension.upper()) or filename.endswith(nir_band_id_suffix + file_extension.lower())
            
            print(f"DEBUG: {filename} ends with Red suffix? {is_red}. Ends with NIR suffix? {is_nir}") # DEBUG PRINT

            if is_red:
                if 'red' in potential_files[scene_id]:
                    print(f"Warning: Multiple Red files found for scene_id ({scene_id}). Overwriting {potential_files[scene_id]['red']} with {f_path}")
                potential_files[scene_id]['red'] = f_path
            elif is_nir:
                if 'nir' in potential_files[scene_id]:
                    print(f"Warning: Multiple NIR files found for scene_id ({scene_id}). Overwriting {potential_files[scene_id]['nir']} with {f_path}")
                potential_files[scene_id]['nir'] = f_path
            else: # DEBUG PRINT
                print(f"DEBUG: Filename {filename} matched scene_id regex but not specific band suffix.")

    for scene_id, bands in potential_files.items():
        if 'red' in bands and 'nir' in bands:
            pairs.append((bands['red'], bands['nir']))
            print(f"DEBUG: Successfully paired scene_id {scene_id}") # DEBUG PRINT
        else:
            print(f"Warning: Missing Red or NIR band for scene_id ({scene_id}). Found: {bands}")
            
    return pairs

# --- MAIN SCRIPT EXECUTION ---
if __name__ == "__main__":
    # --- USER: SET YOUR PATHS AND FILE NAMING CONVENTIONS HERE ---
    
    # 1. Path to the root folder containing your Red_bands and NIR_bands subfolders
    # This path MUST be the parent directory of 'Red_bands' and 'NIR_bands'.
    # Example: C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/Data/Landsat_Raw/
    landsat_input_directory = "C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI" 

    # 2. Path to save the calculated NDVI rasters (individual scenes)
    # This path should be: Dam_Suitability_Analysis/Data/Processed_Rasters/NDVI_Individual/
    ndvi_output_directory = "C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI" 
    
    # 3. Keywords and suffixes based on your *actual* Landsat Level-1 filenames
    # Example: LC09_L1TP_148043_20240211_20240211_02_T1_B4.TIF
    red_filename_keyword = "_B4"    
    nir_filename_keyword = "_B5"    
    red_band_id_suffix = "_B4"      
    nir_band_id_suffix = "_B5"      
    file_extension = ".TIF"         # Or ".tif" if your files use lowercase

    # --- END OF USER SETTINGS ---

    # Create output directory if it doesn't exist
    if not os.path.exists(ndvi_output_directory):
        os.makedirs(ndvi_output_directory)
        print(f"Created output directory: {ndvi_output_directory}")

    # Find all Red and NIR band pairs based on the custom naming convention
    band_pairs = find_band_pairs_custom(landsat_input_directory, 
                                       red_filename_keyword, 
                                       nir_filename_keyword,
                                       red_band_id_suffix, 
                                       nir_band_id_suffix,
                                       file_extension)

    if not band_pairs:
        print(f"\nNo Red and NIR band pairs found in '{landsat_input_directory}'.")
        print("Please ensure your `landsat_input_directory` is correct and contains `Red_bands` and `NIR_bands` subfolders with the appropriate `.TIF` files.")
        print("Also, double-check that your filenames match the expected suffixes like '_B4.TIF' and '_B5.TIF'.")
    else:
        print(f"\nFound {len(band_pairs)} Red/NIR band pairs to process.")

        for i, (red_path, nir_path) in enumerate(band_pairs):
            print(f"\nProcessing pair {i+1}/{len(band_pairs)}:")
            
            # Define output filename for the NDVI raster
            # This extracts the unique part of the filename before the _B4.TIF or _B5.TIF suffix
            red_basename = os.path.basename(red_path)
            scene_id_match = re.search(r'(.*?)_B[45]\.' + re.escape(file_extension) + '$', red_basename, re.IGNORECASE)
            scene_id_str = scene_id_match.group(1) if scene_id_match else "UNKNOWN_SCENE"
            
            output_ndvi_file = os.path.join(ndvi_output_directory, f"NDVI_({scene_id_str}).TIF")
            
            calculate_ndvi(red_path, nir_path, output_ndvi_file)
            
    print("\nNDVI processing complete.")
# Out:
# Found 2 files with extension '.TIF' in 'C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI' (and its 'Red_bands'/'NIR_bands' subdirectories).
# DEBUG: Processing filename: LC08_L1TP_147048_20241228_20250104_02_T1_B5.TIF
# DEBUG: Processing filename: LC08_L1TP_147048_20241228_20250104_02_T1_B4.TIF
#
# No Red and NIR band pairs found in 'C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI'.
# Please ensure your `landsat_input_directory` is correct and contains `Red_bands` and `NIR_bands` subfolders with the appropriate `.TIF` files.
# Also, double-check that your filenames match the expected suffixes like '_B4.TIF' and '_B5.TIF'.
#
# NDVI processing complete.

# %%
import os
import glob
import rasterio
import numpy as np
import re # For using regular expressions to extract scene IDs

def calculate_ndvi(red_file_path, nir_file_path, output_file_path):
    """
    Calculates NDVI from Red and NIR band files and saves the result.
    """
    try:
        scale_factor = 0.0000275 # For Landsat Level-1 to TOA reflectance
        offset = -0.2
        
        with rasterio.open(red_file_path) as red_src:
            red_profile = red_src.profile
            red_int = red_src.read(1).astype('float32')
            red = (red_int * scale_factor) + offset
            if red_src.nodata is not None:
                red[red_int == red_src.nodata] = np.nan

        with rasterio.open(nir_file_path) as nir_src:
            nir_int = nir_src.read(1).astype('float32')
            nir = (nir_int * scale_factor) + offset
            if nir_src.nodata is not None:
                nir[nir_int == nir_src.nodata] = np.nan
        
        np.seterr(divide='ignore', invalid='ignore')
        numerator = nir - red
        denominator = nir + red
        ndvi = numerator / denominator
        
        output_nodata = -9999.0
        ndvi[np.isinf(ndvi)] = output_nodata
        ndvi[np.isnan(ndvi)] = output_nodata
        ndvi[denominator == 0] = output_nodata
        
        valid_ndvi_mask = (ndvi >= -1) & (ndvi <= 1)
        ndvi[~valid_ndvi_mask & (ndvi != output_nodata)] = output_nodata

        profile = red_profile
        profile.update(
            dtype=rasterio.float32,
            count=1,
            compress='lzw',
            nodata=output_nodata
        )
        
        with rasterio.open(output_file_path, 'w', **profile) as dst:
            dst.write(ndvi.astype(rasterio.float32), 1)
            
        print(f"Successfully calculated NDVI and saved to: {output_file_path}")

    except Exception as e:
        print(f"Error processing {os.path.basename(red_file_path)} or {os.path.basename(nir_file_path)}: {e}")

def find_band_pairs_custom(input_dir, 
                           red_filename_keyword="", 
                           nir_filename_keyword="", 
                           red_band_id_suffix="_B4", 
                           nir_band_id_suffix="_B5",
                           file_extension=".TIF"):
    """
    Finds pairs of Red and NIR band files based on common unique scene IDs
    and band identifier suffixes.
    It explicitly looks for Red_bands/ and NIR_bands/ subfolders within input_dir.
    """
    pairs = []
    
    # MODIFIED REGEX: Captures everything before _B4 or _B5, then directly matches the extension.
    # It assumes the unique scene ID is followed by _B4 or _B5, then the exact file_extension.
    scene_id_regex = re.compile(r'(.*?)_B[45]' + re.escape(file_extension) + '$', re.IGNORECASE) 

    potential_files = {} 

    red_bands_dir = os.path.join(input_dir, 'Red_bands')
    nir_bands_dir = os.path.join(input_dir, 'NIR_bands')

    all_red_files = glob.glob(os.path.join(red_bands_dir, f'*{red_band_id_suffix}{file_extension.lower()}')) + \
                    glob.glob(os.path.join(red_bands_dir, f'*{red_band_id_suffix}{file_extension.upper()}'))
    
    all_nir_files = glob.glob(os.path.join(nir_bands_dir, f'*{nir_band_id_suffix}{file_extension.lower()}')) + \
                    glob.glob(os.path.join(nir_bands_dir, f'*{nir_band_id_suffix}{file_extension.upper()}'))

    all_tif_files = list(set(all_red_files + all_nir_files)) 

    print(f"Found {len(all_tif_files)} files with extension '{file_extension}' in '{input_dir}' (and its 'Red_bands'/'NIR_bands' subdirectories).")
    if not all_tif_files:
        return pairs

    for f_path in all_tif_files:
        filename = os.path.basename(f_path)
        print(f"DEBUG: Processing filename: {filename}") 
        
        scene_id_match = scene_id_regex.search(filename)
        if scene_id_match:
            scene_id = scene_id_match.group(1)
            print(f"DEBUG: Extracted scene_id: {scene_id} from {filename}") 
            
            if scene_id not in potential_files:
                potential_files[scene_id] = {}
            
            is_red = filename.endswith(red_band_id_suffix + file_extension.upper()) or filename.endswith(red_band_id_suffix + file_extension.lower())
            is_nir = filename.endswith(nir_band_id_suffix + file_extension.upper()) or filename.endswith(nir_band_id_suffix + file_extension.lower())
            
            print(f"DEBUG: {filename} ends with Red suffix? {is_red}. Ends with NIR suffix? {is_nir}") 

            if is_red:
                if 'red' in potential_files[scene_id]:
                    print(f"Warning: Multiple Red files found for scene_id ({scene_id}). Overwriting {potential_files[scene_id]['red']} with {f_path}")
                potential_files[scene_id]['red'] = f_path
            elif is_nir:
                if 'nir' in potential_files[scene_id]:
                    print(f"Warning: Multiple NIR files found for scene_id ({scene_id}). Overwriting {potential_files[scene_id]['nir']} with {f_path}")
                potential_files[scene_id]['nir'] = f_path
            else: 
                print(f"DEBUG: Filename {filename} matched scene_id regex but not specific band suffix.")

    for scene_id, bands in potential_files.items():
        if 'red' in bands and 'nir' in bands:
            pairs.append((bands['red'], bands['nir']))
            print(f"DEBUG: Successfully paired scene_id {scene_id}") 
        else:
            print(f"Warning: Missing Red or NIR band for scene_id ({scene_id}). Found: {bands}")
            
    return pairs

# --- MAIN SCRIPT EXECUTION ---
if __name__ == "__main__":
    # --- USER: SET YOUR PATHS AND FILE NAMING CONVENTIONS HERE ---
    
    # 1. Path to the root folder containing your Red_bands and NIR_bands subfolders
    # This path MUST be the parent directory of 'Red_bands' and 'NIR_bands'.
    # Example: C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/Data/Landsat_Raw/
    landsat_input_directory = "C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI" 

    # 2. Path to save the calculated NDVI rasters (individual scenes)
    # This path should be: Dam_Suitability_Analysis/Data/Processed_Rasters/NDVI_Individual/
    ndvi_output_directory = "C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI" 
    
    # 3. Keywords and suffixes based on your *actual* Landsat Level-1 filenames
    # Example: LC09_L1TP_148043_20240211_20240211_02_T1_B4.TIF
    red_filename_keyword = "_B4"    
    nir_filename_keyword = "_B5"    
    red_band_id_suffix = "_B4"      
    nir_band_id_suffix = "_B5"      
    file_extension = ".TIF"         # Or ".tif" if your files use lowercase

    # --- END OF USER SETTINGS ---

    # Create output directory if it doesn't exist
    if not os.path.exists(ndvi_output_directory):
        os.makedirs(ndvi_output_directory)
        print(f"Created output directory: {ndvi_output_directory}")

    # Find all Red and NIR band pairs based on the custom naming convention
    band_pairs = find_band_pairs_custom(landsat_input_directory, 
                                       red_filename_keyword, 
                                       nir_filename_keyword,
                                       red_band_id_suffix, 
                                       nir_band_id_suffix,
                                       file_extension)

    if not band_pairs:
        print(f"\nNo Red and NIR band pairs found in '{landsat_input_directory}'.")
        print("Please ensure your `landsat_input_directory` is correct and contains `Red_bands` and `NIR_bands` subfolders with the appropriate `.TIF` files.")
        print("Also, double-check that your filenames match the expected suffixes like '_B4.TIF' and '_B5.TIF'.")
    else:
        print(f"\nFound {len(band_pairs)} Red/NIR band pairs to process.")

        for i, (red_path, nir_path) in enumerate(band_pairs):
            print(f"\nProcessing pair {i+1}/{len(band_pairs)}:")
            
            # Define output filename for the NDVI raster
            # This extracts the unique part of the filename before the _B4.TIF or _B5.TIF suffix
            red_basename = os.path.basename(red_path)
            scene_id_match = re.search(r'(.*?)_B[45]\.' + re.escape(file_extension) + '$', red_basename, re.IGNORECASE)
            scene_id_str = scene_id_match.group(1) if scene_id_match else "UNKNOWN_SCENE"
            
            output_ndvi_file = os.path.join(ndvi_output_directory, f"NDVI_({scene_id_str}).TIF")
            
            calculate_ndvi(red_path, nir_path, output_ndvi_file)
            
    print("\nNDVI processing complete.")
# Out:
# Found 2 files with extension '.TIF' in 'C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI' (and its 'Red_bands'/'NIR_bands' subdirectories).
# DEBUG: Processing filename: LC08_L1TP_147048_20241228_20250104_02_T1_B5.TIF
# DEBUG: Extracted scene_id: LC08_L1TP_147048_20241228_20250104_02_T1 from LC08_L1TP_147048_20241228_20250104_02_T1_B5.TIF
# DEBUG: LC08_L1TP_147048_20241228_20250104_02_T1_B5.TIF ends with Red suffix? False. Ends with NIR suffix? True
# DEBUG: Processing filename: LC08_L1TP_147048_20241228_20250104_02_T1_B4.TIF
# DEBUG: Extracted scene_id: LC08_L1TP_147048_20241228_20250104_02_T1 from LC08_L1TP_147048_20241228_20250104_02_T1_B4.TIF
# DEBUG: LC08_L1TP_147048_20241228_20250104_02_T1_B4.TIF ends with Red suffix? True. Ends with NIR suffix? False
# DEBUG: Successfully paired scene_id LC08_L1TP_147048_20241228_20250104_02_T1
#
# Found 1 Red/NIR band pairs to process.
#
# Processing pair 1/1:
# Successfully calculated NDVI and saved to: C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI\NDVI_(UNKNOWN_SCENE).TIF
#
# NDVI processing complete.

# %%
import os
import glob
import rasterio
import numpy as np
import re # For using regular expressions to extract scene IDs

def calculate_ndvi(red_file_path, nir_file_path, output_file_path):
    """
    Calculates NDVI from Red and NIR band files and saves the result.
    """
    try:
        scale_factor = 0.0000275 # For Landsat Level-1 to TOA reflectance
        offset = -0.2
        
        with rasterio.open(red_file_path) as red_src:
            red_profile = red_src.profile
            red_int = red_src.read(1).astype('float32')
            red = (red_int * scale_factor) + offset
            if red_src.nodata is not None:
                red[red_int == red_src.nodata] = np.nan

        with rasterio.open(nir_file_path) as nir_src:
            nir_int = nir_src.read(1).astype('float32')
            nir = (nir_int * scale_factor) + offset
            if nir_src.nodata is not None:
                nir[nir_int == nir_src.nodata] = np.nan
        
        np.seterr(divide='ignore', invalid='ignore')
        numerator = nir - red
        denominator = nir + red
        ndvi = numerator / denominator
        
        output_nodata = -9999.0
        ndvi[np.isinf(ndvi)] = output_nodata
        ndvi[np.isnan(ndvi)] = output_nodata
        ndvi[denominator == 0] = output_nodata
        
        valid_ndvi_mask = (ndvi >= -1) & (ndvi <= 1)
        ndvi[~valid_ndvi_mask & (ndvi != output_nodata)] = output_nodata

        profile = red_profile
        profile.update(
            dtype=rasterio.float32,
            count=1,
            compress='lzw',
            nodata=output_nodata
        )
        
        with rasterio.open(output_file_path, 'w', **profile) as dst:
            dst.write(ndvi.astype(rasterio.float32), 1)
            
        print(f"Successfully calculated NDVI and saved to: {output_file_path}")

    except Exception as e:
        print(f"Error processing {os.path.basename(red_file_path)} or {os.path.basename(nir_file_path)}: {e}")

def find_band_pairs_custom(input_dir, 
                           red_filename_keyword="", 
                           nir_filename_keyword="", 
                           red_band_id_suffix="_B4", 
                           nir_band_id_suffix="_B5",
                           file_extension=".TIF"):
    """
    Finds pairs of Red and NIR band files based on common unique scene IDs
    and band identifier suffixes.
    It explicitly looks for Red_bands/ and NIR_bands/ subfolders within input_dir.
    """
    pairs = []
    
    # MODIFIED REGEX: Captures everything before _B4 or _B5, then directly matches the extension.
    scene_id_regex = re.compile(r'(.*?)_B[45]' + re.escape(file_extension) + '$', re.IGNORECASE) 

    potential_files = {} 

    red_bands_dir = os.path.join(input_dir, 'Red_bands')
    nir_bands_dir = os.path.join(input_dir, 'NIR_bands')

    all_red_files = glob.glob(os.path.join(red_bands_dir, f'*{red_band_id_suffix}{file_extension.lower()}')) + \
                    glob.glob(os.path.join(red_bands_dir, f'*{red_band_id_suffix}{file_extension.upper()}'))
    
    all_nir_files = glob.glob(os.path.join(nir_bands_dir, f'*{nir_band_id_suffix}{file_extension.lower()}')) + \
                    glob.glob(os.path.join(nir_bands_dir, f'*{nir_band_id_suffix}{file_extension.upper()}'))

    all_tif_files = list(set(all_red_files + all_nir_files)) 

    print(f"Found {len(all_tif_files)} files with extension '{file_extension}' in '{input_dir}' (and its 'Red_bands'/'NIR_bands' subdirectories).")
    if not all_tif_files:
        return pairs

    for f_path in all_tif_files:
        filename = os.path.basename(f_path)
        print(f"DEBUG: Processing filename: {filename}") 
        
        scene_id_match = scene_id_regex.search(filename)
        if scene_id_match:
            scene_id = scene_id_match.group(1)
            print(f"DEBUG: Extracted scene_id: {scene_id} from {filename}") 
            
            if scene_id not in potential_files:
                potential_files[scene_id] = {}
            
            is_red = filename.endswith(red_band_id_suffix + file_extension.upper()) or filename.endswith(red_band_id_suffix + file_extension.lower())
            is_nir = filename.endswith(nir_band_id_suffix + file_extension.upper()) or filename.endswith(nir_band_id_suffix + file_extension.lower())
            
            print(f"DEBUG: {filename} ends with Red suffix? {is_red}. Ends with NIR suffix? {is_nir}") 

            if is_red:
                if 'red' in potential_files[scene_id]:
                    print(f"Warning: Multiple Red files found for scene_id ({scene_id}). Overwriting {potential_files[scene_id]['red']} with {f_path}")
                potential_files[scene_id]['red'] = f_path
            elif is_nir:
                if 'nir' in potential_files[scene_id]:
                    print(f"Warning: Multiple NIR files found for scene_id ({scene_id}). Overwriting {potential_files[scene_id]['nir']} with {f_path}")
                potential_files[scene_id]['nir'] = f_path
            else: 
                print(f"DEBUG: Filename {filename} matched scene_id regex but not specific band suffix.")

    for scene_id, bands in potential_files.items():
        if 'red' in bands and 'nir' in bands:
            pairs.append((bands['red'], bands['nir']))
            print(f"DEBUG: Successfully paired scene_id {scene_id}") 
        else:
            print(f"Warning: Missing Red or NIR band for scene_id ({scene_id}). Found: {bands}")
            
    return pairs

# --- MAIN SCRIPT EXECUTION ---
if __name__ == "__main__":
    # --- USER: SET YOUR PATHS AND FILE NAMING CONVENTIONS HERE ---
    
    # 1. Path to the root folder containing your Red_bands and NIR_bands subfolders
    # This path MUST be the parent directory of 'Red_bands' and 'NIR_bands'.
    # Example: C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/Data/Landsat_Raw/
    landsat_input_directory = "C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI" 

    # 2. Path to save the calculated NDVI rasters (individual scenes)
    # This path should be: Dam_Suitability_Analysis/Data/Processed_Rasters/NDVI_Individual/
    ndvi_output_directory = "C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI" 
    
    # 3. Keywords and suffixes based on your *actual* Landsat Level-1 filenames
    # Example: LC09_L1TP_148043_20240211_20240211_02_T1_B4.TIF
    red_filename_keyword = "_B4"    
    nir_filename_keyword = "_B5"    
    red_band_id_suffix = "_B4"      
    nir_band_id_suffix = "_B5"      
    file_extension = ".TIF"         # Or ".tif" if your files use lowercase

    # --- END OF USER SETTINGS ---

    # Create output directory if it doesn't exist
    if not os.path.exists(ndvi_output_directory):
        os.makedirs(ndvi_output_directory)
        print(f"Created output directory: {ndvi_output_directory}")

    # Find all Red and NIR band pairs based on the custom naming convention
    band_pairs = find_band_pairs_custom(landsat_input_directory, 
                                       red_filename_keyword, 
                                       nir_filename_keyword,
                                       red_band_id_suffix, 
                                       nir_band_id_suffix,
                                       file_extension)

    if not band_pairs:
        print(f"\nNo Red and NIR band pairs found in '{landsat_input_directory}'.")
        print("Please ensure your `landsat_input_directory` is correct and contains `Red_bands` and `NIR_bands` subfolders with the appropriate `.TIF` files.")
        print("Also, double-check that your filenames match the expected suffixes like '_B4.TIF' and '_B5.TIF'.")
    else:
        print(f"\nFound {len(band_pairs)} Red/NIR band pairs to process.")

        for i, (red_path, nir_path) in enumerate(band_pairs):
            print(f"\nProcessing pair {i+1}/{len(band_pairs)}:")
            
            # Define output filename for the NDVI raster
            # This extracts the unique part of the filename before the _B4.TIF or _B5.TIF suffix
            red_basename = os.path.basename(red_path)
            # MODIFIED: Use the same robust regex for scene_id extraction here as in find_band_pairs_custom
            scene_id_match = re.search(r'(.*?)_B[45]' + re.escape(file_extension) + '$', red_basename, re.IGNORECASE)
            scene_id_str = scene_id_match.group(1) if scene_id_match else "UNKNOWN_SCENE"
            
            output_ndvi_file = os.path.join(ndvi_output_directory, f"NDVI_({scene_id_str}).TIF")
            
            calculate_ndvi(red_path, nir_path, output_ndvi_file)
            
    print("\nNDVI processing complete.")
# Out:
# Found 2 files with extension '.TIF' in 'C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI' (and its 'Red_bands'/'NIR_bands' subdirectories).
# DEBUG: Processing filename: LC08_L1TP_147048_20241228_20250104_02_T1_B5.TIF
# DEBUG: Extracted scene_id: LC08_L1TP_147048_20241228_20250104_02_T1 from LC08_L1TP_147048_20241228_20250104_02_T1_B5.TIF
# DEBUG: LC08_L1TP_147048_20241228_20250104_02_T1_B5.TIF ends with Red suffix? False. Ends with NIR suffix? True
# DEBUG: Processing filename: LC08_L1TP_147048_20241228_20250104_02_T1_B4.TIF
# DEBUG: Extracted scene_id: LC08_L1TP_147048_20241228_20250104_02_T1 from LC08_L1TP_147048_20241228_20250104_02_T1_B4.TIF
# DEBUG: LC08_L1TP_147048_20241228_20250104_02_T1_B4.TIF ends with Red suffix? True. Ends with NIR suffix? False
# DEBUG: Successfully paired scene_id LC08_L1TP_147048_20241228_20250104_02_T1
#
# Found 1 Red/NIR band pairs to process.
#
# Processing pair 1/1:
# Successfully calculated NDVI and saved to: C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI\NDVI_(LC08_L1TP_147048_20241228_20250104_02_T1).TIF
#
# NDVI processing complete.

# %%
import os
import glob
import rasterio
import numpy as np
import re # For using regular expressions to extract scene IDs

def calculate_ndvi(red_file_path, nir_file_path, output_file_path):
    """
    Calculates NDVI from Red and NIR band files and saves the result.
    Includes debug prints to trace value progression.
    """
    try:
        # --- Define Landsat Collection 2 Level 2 scaling factors ---
        # These are typical scaling factors for Landsat Level-2 Surface Reflectance (SR) products.
        # If you downloaded Level-1 data, these might convert to TOA reflectance, not surface reflectance.
        # For Level-1 data, proper atmospheric correction is usually needed for accurate surface reflectance.
        scale_factor = 0.0000275
        offset = -0.2
        
        with rasterio.open(red_file_path) as red_src:
            red_profile = red_src.profile
            red_int = red_src.read(1).astype('float32')
            print(f"DEBUG: {os.path.basename(red_file_path)} - Raw int Min: {np.nanmin(red_int):.2f}, Max: {np.nanmax(red_int):.2f}") # ADDED DEBUG
            red = (red_int * scale_factor) + offset
            print(f"DEBUG: {os.path.basename(red_file_path)} - Scaled float Min: {np.nanmin(red):.4f}, Max: {np.nanmax(red):.4f}") # ADDED DEBUG
            if red_src.nodata is not None:
                red[red_int == red_src.nodata] = np.nan

        with rasterio.open(nir_file_path) as nir_src:
            nir_int = nir_src.read(1).astype('float32')
            print(f"DEBUG: {os.path.basename(nir_file_path)} - Raw int Min: {np.nanmin(nir_int):.2f}, Max: {np.nanmax(nir_int):.2f}") # ADDED DEBUG
            nir = (nir_int * scale_factor) + offset
            print(f"DEBUG: {os.path.basename(nir_file_path)} - Scaled float Min: {np.nanmin(nir):.4f}, Max: {np.nanmax(nir):.4f}") # ADDED DEBUG
            if nir_src.nodata is not None:
                nir[nir_int == nir_src.nodata] = np.nan
        
        np.seterr(divide='ignore', invalid='ignore')
        numerator = nir - red
        denominator = nir + red
        
        print(f"DEBUG: Numerator Min: {np.nanmin(numerator):.4f}, Max: {np.nanmax(numerator):.4f}") # ADDED DEBUG
        print(f"DEBUG: Denominator Min: {np.nanmin(denominator):.4f}, Max: {np.nanmax(denominator):.4f}") # ADDED DEBUG
        
        ndvi = numerator / denominator
        print(f"DEBUG: NDVI (raw calculated) Min: {np.nanmin(ndvi):.4f}, Max: {np.nanmax(ndvi):.4f}") # ADDED DEBUG
        
        output_nodata = -9999.0
        ndvi[np.isinf(ndvi)] = output_nodata
        ndvi[np.isnan(ndvi)] = output_nodata
        ndvi[denominator == 0] = output_nodata # Handle division by zero explicitly
        
        valid_ndvi_mask = (ndvi >= -1) & (ndvi <= 1)
        # Only set values outside [-1, 1] to NoData if they are not already NoData
        ndvi[~valid_ndvi_mask & (ndvi != output_nodata)] = output_nodata
        print(f"DEBUG: NDVI (final masked) Min: {np.nanmin(ndvi):.4f}, Max: {np.nanmax(ndvi):.4f}") # ADDED DEBUG


        profile = red_profile
        profile.update(
            dtype=rasterio.float32,
            count=1,
            compress='lzw',
            nodata=output_nodata
        )
        
        with rasterio.open(output_file_path, 'w', **profile) as dst:
            dst.write(ndvi.astype(rasterio.float32), 1)
            
        print(f"Successfully calculated NDVI and saved to: {output_file_path}")

    except Exception as e:
        print(f"Error processing {os.path.basename(red_file_path)} or {os.path.basename(nir_file_path)}: {e}")

def find_band_pairs_custom(input_dir, 
                           red_filename_keyword="", 
                           nir_filename_keyword="", 
                           red_band_id_suffix="_B4", 
                           nir_band_id_suffix="_B5",
                           file_extension=".TIF"):
    """
    Finds pairs of Red and NIR band files based on common unique scene IDs
    and band identifier suffixes.
    It explicitly looks for Red_bands/ and NIR_bands/ subfolders within input_dir.
    """
    pairs = []
    
    # MODIFIED REGEX: Captures everything before _B4 or _B5, then directly matches the extension.
    scene_id_regex = re.compile(r'(.*?)_B[45]' + re.escape(file_extension) + '$', re.IGNORECASE) 

    potential_files = {} 

    red_bands_dir = os.path.join(input_dir, 'Red_bands')
    nir_bands_dir = os.path.join(input_dir, 'NIR_bands')

    all_red_files = glob.glob(os.path.join(red_bands_dir, f'*{red_band_id_suffix}{file_extension.lower()}')) + \
                    glob.glob(os.path.join(red_bands_dir, f'*{red_band_id_suffix}{file_extension.upper()}'))
    
    all_nir_files = glob.glob(os.path.join(nir_bands_dir, f'*{nir_band_id_suffix}{file_extension.lower()}')) + \
                    glob.glob(os.path.join(nir_bands_dir, f'*{nir_band_id_suffix}{file_extension.upper()}'))

    all_tif_files = list(set(all_red_files + all_nir_files)) 

    print(f"Found {len(all_tif_files)} files with extension '{file_extension}' in '{input_dir}' (and its 'Red_bands'/'NIR_bands' subdirectories).")
    if not all_tif_files:
        return pairs

    for f_path in all_tif_files:
        filename = os.path.basename(f_path)
        print(f"DEBUG: Processing filename: {filename}") 
        
        scene_id_match = scene_id_regex.search(filename)
        if scene_id_match:
            scene_id = scene_id_match.group(1)
            print(f"DEBUG: Extracted scene_id: {scene_id} from {filename}") 
            
            is_red = filename.endswith(red_band_id_suffix + file_extension.upper()) or filename.endswith(red_band_id_suffix + file_extension.lower())
            is_nir = filename.endswith(nir_band_id_suffix + file_extension.upper()) or filename.endswith(nir_band_id_suffix + file_extension.lower())
            
            print(f"DEBUG: {filename} ends with Red suffix? {is_red}. Ends with NIR suffix? {is_nir}") 

            if scene_id not in potential_files:
                potential_files[scene_id] = {}

            if is_red:
                if 'red' in potential_files[scene_id]:
                    print(f"Warning: Multiple Red files found for scene_id ({scene_id}). Overwriting {potential_files[scene_id]['red']} with {f_path}")
                potential_files[scene_id]['red'] = f_path
            elif is_nir:
                if 'nir' in potential_files[scene_id]:
                    print(f"Warning: Multiple NIR files found for scene_id ({scene_id}). Overwriting {potential_files[scene_id]['nir']} with {f_path}")
                potential_files[scene_id]['nir'] = f_path
            else: 
                print(f"DEBUG: Filename {filename} matched scene_id regex but not specific band suffix.")

    for scene_id, bands in potential_files.items():
        if 'red' in bands and 'nir' in bands:
            pairs.append((bands['red'], bands['nir']))
            print(f"DEBUG: Successfully paired scene_id {scene_id}") 
        else:
            print(f"Warning: Missing Red or NIR band for scene_id ({scene_id}). Found: {bands}")
            
    return pairs

# --- MAIN SCRIPT EXECUTION ---
if __name__ == "__main__":
    # --- USER: SET YOUR PATHS AND FILE NAMING CONVENTIONS HERE ---
    
    # 1. Path to the root folder containing your Red_bands and NIR_bands subfolders
    # This path MUST be the parent directory of 'Red_bands' and 'NIR_bands'.
    # Example: C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/Data/Landsat_Raw/
    landsat_input_directory = "C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI" 

    # 2. Path to save the calculated NDVI rasters (individual scenes)
    # This path should be: Dam_Suitability_Analysis/Data/Processed_Rasters/NDVI_Individual/
    ndvi_output_directory = "C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI" 
    
    # 3. Keywords and suffixes based on your *actual* Landsat Level-1 filenames
    # Example: LC09_L1TP_148043_20240211_20240211_02_T1_B4.TIF
    red_filename_keyword = "_B4"    
    nir_filename_keyword = "_B5"    
    red_band_id_suffix = "_B4"      
    nir_band_id_suffix = "_B5"      
    file_extension = ".TIF"         # Or ".tif" if your files use lowercase

    # --- END OF USER SETTINGS ---

    # Create output directory if it doesn't exist
    if not os.path.exists(ndvi_output_directory):
        os.makedirs(ndvi_output_directory)
        print(f"Created output directory: {ndvi_output_directory}")

    # Find all Red and NIR band pairs based on the custom naming convention
    band_pairs = find_band_pairs_custom(landsat_input_directory, 
                                       red_filename_keyword, 
                                       nir_filename_keyword,
                                       red_band_id_suffix, 
                                       nir_band_id_suffix,
                                       file_extension)

    if not band_pairs:
        print(f"\nNo Red and NIR band pairs found in '{landsat_input_directory}'.")
        print("Please ensure your `landsat_input_directory` is correct and contains `Red_bands` and `NIR_bands` subfolders with the appropriate `.TIF` files.")
        print("Also, double-check that your filenames match the expected suffixes like '_B4.TIF' and '_B5.TIF'.")
    else:
        print(f"\nFound {len(band_pairs)} Red/NIR band pairs to process.")

        for i, (red_path, nir_path) in enumerate(band_pairs):
            print(f"\nProcessing pair {i+1}/{len(band_pairs)}:")
            
            # Define output filename for the NDVI raster
            # This extracts the unique part of the filename before the _B4.TIF or _B5.TIF suffix
            red_basename = os.path.basename(red_path)
            scene_id_match = re.search(r'(.*?)_B[45]' + re.escape(file_extension) + '$', red_basename, re.IGNORECASE)
            scene_id_str = scene_id_match.group(1) if scene_id_match else "UNKNOWN_SCENE"
            
            output_ndvi_file = os.path.join(ndvi_output_directory, f"NDVI_({scene_id_str}).TIF")
            
            calculate_ndvi(red_path, nir_path, output_ndvi_file)
            
    print("\nNDVI processing complete.")
# Out:
# Found 2 files with extension '.TIF' in 'C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI' (and its 'Red_bands'/'NIR_bands' subdirectories).
# DEBUG: Processing filename: LC08_L1TP_147048_20241228_20250104_02_T1_B5.TIF
# DEBUG: Extracted scene_id: LC08_L1TP_147048_20241228_20250104_02_T1 from LC08_L1TP_147048_20241228_20250104_02_T1_B5.TIF
# DEBUG: LC08_L1TP_147048_20241228_20250104_02_T1_B5.TIF ends with Red suffix? False. Ends with NIR suffix? True
# DEBUG: Processing filename: LC08_L1TP_147048_20241228_20250104_02_T1_B4.TIF
# DEBUG: Extracted scene_id: LC08_L1TP_147048_20241228_20250104_02_T1 from LC08_L1TP_147048_20241228_20250104_02_T1_B4.TIF
# DEBUG: LC08_L1TP_147048_20241228_20250104_02_T1_B4.TIF ends with Red suffix? True. Ends with NIR suffix? False
# DEBUG: Successfully paired scene_id LC08_L1TP_147048_20241228_20250104_02_T1
#
# Found 1 Red/NIR band pairs to process.
#
# Processing pair 1/1:
# DEBUG: LC08_L1TP_147048_20241228_20250104_02_T1_B4.TIF - Raw int Min: 0.00, Max: 47511.00
# DEBUG: LC08_L1TP_147048_20241228_20250104_02_T1_B4.TIF - Scaled float Min: -0.2000, Max: 1.1066
# DEBUG: LC08_L1TP_147048_20241228_20250104_02_T1_B5.TIF - Raw int Min: 0.00, Max: 52740.00
# DEBUG: LC08_L1TP_147048_20241228_20250104_02_T1_B5.TIF - Scaled float Min: -0.2000, Max: 1.2503
# DEBUG: Numerator Min: -0.1315, Max: 0.4727
# DEBUG: Denominator Min: -0.0820, Max: 2.3569
# DEBUG: NDVI (raw calculated) Min: -5298.9214, Max: 4218.7954
# DEBUG: NDVI (final masked) Min: -9999.0000, Max: 1.0000
# Successfully calculated NDVI and saved to: C:/Users/Lenovo/Documents/Dam_Suitability_Analysis/DATA/LANDSAT/NDVI\NDVI_(LC08_L1TP_147048_20241228_20250104_02_T1).TIF
#
# NDVI processing complete.
